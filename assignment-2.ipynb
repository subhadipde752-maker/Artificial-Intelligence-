# %%
from sklearn.datasets import load_digits 
import matplotlib.pyplot as plt

digits= load_digits() 
fig,axes=plt.subplots(2,5,figsize=(10,5))

for i,ax in enumerate(axes.flat): 
  ax.imshow(digits.images[i],cmap="grey")
  ax.set_title(f"digit:{digits.target[i]}")
  ax.axis("off")

plt.tight_layout(), 
plt.show()

# %%
# WAP in python to print the description of iris datasets
# wap to display number of a) rows and columns 
# b) column names 
# c) datatypes
# wap to count the number of samples available in iris datasets and digit datasets
# Import necessary library
# Import necessary library
try:
    from sklearn.datasets import load_iris
except ImportError:
    print("Error: scikit-learn is not installed. Please install it using 'pip install scikit-learn'")
    exit(1)

def main():
    # Load the Iris dataset
    iris = load_iris()

    # Print the description
    print("=== Iris Dataset Description ===\n")
    if hasattr(iris, 'DESCR') and iris.DESCR:
        print(iris.DESCR)
    else:
        print("No description available for this dataset.")

if __name__ == "__main__":
    main()
# Out:
# === Iris Dataset Description ===
#
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
import panda as pd
from sklearn.datasets import load_iris
iris=
